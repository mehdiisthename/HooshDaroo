# %%
import json

# %%
with open('rag_chunks_v5.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
chunks = [c['embedding_text'] for c in data]
maxchunk = sorted(chunks, key= lambda x: len(x))
print(len(maxchunk[-1]))
# Out:
# 1456

# %%
len(maxchunk[-1].split())
# Out:
# 288
